# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/sel_data_v1.csv')
# Out:
# G:\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (33,35,47,63,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(3)
# Out:
#   browser  browser_version first_browser_language first_referrer  \
# 0  chrome             56.0                    NaN            NaN
# 1     NaN              NaN                  zh-CN            NaN
# 2  chrome             56.0                    NaN            NaN
#
#   first_referrer_host         first_visit_time               ip is_first_day  \
# 0                 NaN                      NaN   219.135.131.99         True
# 1                 NaN  2017-03-06 17:04:10.999              NaN          NaN
# 2                 NaN                      NaN  111.204.198.242         True
#
#   is_first_time latest_referrer        ...        referrerUrl requestBtn  \
# 0         False             NaN        ...                NaN        NaN
# 1           NaN             NaN        ...                NaN        NaN
# 2          True             NaN        ...                NaN        NaN
#
#   result                                   session_page_url siteUrl site_url  \
# 0    NaN  https://www.sensorsdata.cn/?utm_source=baidu&u...     NaN      NaN
# 1    NaN                                                NaN     NaN      NaN
# 2    NaN                    https://sensorsdata.cn/?ch=demo     NaN      NaN
#
#            time              type  url_path.1 verification_code
# 0  1.488791e+12             track         NaN               NaN
# 1  1.490958e+12  profile_set_once         NaN               NaN
# 2  1.488791e+12             track         NaN               NaN
#
# [3 rows x 65 columns]

# %%
df.columns
# Out:
# Index([u'browser', u'browser_version', u'first_browser_language',
#        u'first_referrer', u'first_referrer_host', u'first_visit_time', u'ip',
#        u'is_first_day', u'is_first_time', u'latest_referrer',
#        u'latest_referrer_host', u'latest_utm_campaign', u'latest_utm_content',
#        u'latest_utm_medium', u'latest_utm_source', u'latest_utm_term',
#        u'model', u'os', u'os_version', u'referrer', u'referrer_host',
#        u'screen_height', u'screen_width', u'title', u'url', u'url_path',
#        u'utm_campaign', u'utm_content', u'utm_medium', u'utm_source',
#        u'utm_term', u'latest_ch', u'nocache', u'session_from_url',
#        u'session_referrer', u'session_referrer_domain',
#        u'session_referrer_host', u'ch', u'company', u'contact', u'distinct_id',
#        u'email', u'event', u'from_url', u'info', u'isMsg', u'isSuccess',
#        u'jssdk_error', u'name', u'page', u'pagePosition', u'pageStayTime',
#        u'pageUrl', u'project_name', u'referrHostUrl', u'referrerUrl',
#        u'requestBtn', u'result', u'session_page_url', u'siteUrl', u'site_url',
#        u'time', u'type', u'url_path.1', u'verification_code'],
#       dtype='object')

# %%
df[(df.event.isnull()) & (df.title.notnull())]
# Out:
# Empty DataFrame
# Columns: [browser, browser_version, first_browser_language, first_referrer, first_referrer_host, first_visit_time, ip, is_first_day, is_first_time, latest_referrer, latest_referrer_host, latest_utm_campaign, latest_utm_content, latest_utm_medium, latest_utm_source, latest_utm_term, model, os, os_version, referrer, referrer_host, screen_height, screen_width, title, url, url_path, utm_campaign, utm_content, utm_medium, utm_source, utm_term, latest_ch, nocache, session_from_url, session_referrer, session_referrer_domain, session_referrer_host, ch, company, contact, distinct_id, email, event, from_url, info, isMsg, isSuccess, jssdk_error, name, page, pagePosition, pageStayTime, pageUrl, project_name, referrHostUrl, referrerUrl, requestBtn, result, session_page_url, siteUrl, site_url, time, type, url_path.1, verification_code]
# Index: []
#
# [0 rows x 65 columns]

# %%
df[(df['info'].notnull())].event.value_counts(dropna = False)
# Out:
# verify_cellphone_code    372
# click_send_cellphone     366
# Name: event, dtype: int64

# %%
df.event.value_counts(dropna = False)
# Out:
# $pageview                22038
# btnClick                  9394
# index_leave               7115
# NaN                       6485
# demo_leave                2388
# about_leave                696
# courses_leave              628
# formSubmit                 535
# courses_play_leave         507
# click_send_cellphone       400
# verify_cellphone_code      372
# clickSubmit                353
# page_close                 138
# Name: event, dtype: int64

# %%
df[(df['requestBtn'].notnull())].event.value_counts(dropna = False)
# Out:
# btnClick       2074
# formSubmit      535
# clickSubmit     353
# Name: event, dtype: int64

# %%
df[(df['isMsg'].notnull())].event.value_counts(dropna = False)
# Out:
# formSubmit    313
# Name: event, dtype: int64

# %%
df[(df.event == 'formSubmit')].shape
# Out:
# (535, 65)

# %%
df[(df.event == 'formSubmit')].isMsg.value_counts(dropna = False)
# Out:
# NaN      222
# True     167
# False    146
# Name: isMsg, dtype: int64

# %%
df[(df['page'].notnull())].event.value_counts(dropna = False)
# Out:
# btnClick    7994
# Name: event, dtype: int64

# %%
df[(df['from_url'].notnull()) & (df['event'] != 'formSubmit')].event.value_counts(dropna = False)
# Out:
# clickSubmit    300
# Name: event, dtype: int64

# %%
df[(df['latest_utm_campaign'].notnull())].event.value_counts(dropna = False)
# Out:
# $pageview                12814
# btnClick                  5881
# index_leave               5012
# demo_leave                1367
# about_leave                387
# formSubmit                 354
# courses_leave              308
# courses_play_leave         282
# click_send_cellphone       278
# verify_cellphone_code      267
# clickSubmit                262
# page_close                  41
# Name: event, dtype: int64

# %%
df[(df['latest_utm_source'].notnull())].event.value_counts(dropna = False)
# Out:
# $pageview                13013
# btnClick                  5970
# index_leave               5088
# demo_leave                1381
# about_leave                396
# formSubmit                 355
# courses_leave              312
# courses_play_leave         282
# click_send_cellphone       279
# verify_cellphone_code      269
# clickSubmit                263
# page_close                  41
# Name: event, dtype: int64

# %%
null_event_df = df[(df.event.isnull())]

# %%
null_event_df.shape
# Out:
# (6485, 65)

# %%
for col_name in null_event_df.columns:
    print col_name
    print null_event_df[col_name].value_counts(dropna = False)
    print "***********************************"
# Out:
# browser
# NaN    6485
# Name: browser, dtype: int64
# ***********************************
# browser_version
# NaN    6485
# Name: browser_version, dtype: int64
# ***********************************
# first_browser_language
# zh-CN    4893
# zh-cn     874
# en-US     406
# NaN       196
# en-us      50
# en-GB      15
# C          14
# ru          8
# zh-tw       7
# zh-TW       7
# ja-jp       3
# ru-RU       2
# ja          2
# de-de       1
# ja-JP       1
# fr          1
# en-sg       1
# zh-HK       1
# zh          1
# hy-AM       1
# ko          1
# Name: first_browser_language, dtype: int64
# ***********************************
# first_referrer
# https://www.baidu.com/baidu.php                                                                                                                                                                             2431
# NaN                                                                                                                                                                                                         1757
# https://www.baidu.com/link                                                                                                                                                                                   254
# https://www.baidu.com/s                                                                                                                                                                                      198
# https://www.google.com.hk/                                                                                                                                                                                    51
# http://36kr.com/                                                                                                                                                                                              46
# https://www.google.com/                                                                                                                                                                                       42
# https://www.baidu.com/                                                                                                                                                                                        25
# 2017-03-09 01:02:28.873    1
# 2017-03-10 15:17:32.192    1
# 2017-03-09 14:36:10.575    1
# 2017-03-09 12:08:31.399    1
# 2017-03-08 02:20:51.722    1
# 2017-03-09 11:07:36.614    1
# 2017-03-11 21:54:58.995    1
# 2017-03-10 14:26:26.551    1
# 2017-03-11 00:48:56.568    1
# 2017-03-07 11:24:30.608    1
# 2017-03-07 11:01:05.649    1
# 2017-03-06 22:35:35.774    1
# 2017-03-10 17:59:56.186    1
# 2017-03-11 21:48:41.835    1
# 2017-03-10 18:16:41.277    1
# 2017-03-08 17:25:31.886    1
# 2017-03-06 21:53:08.930    1
# 2017-03-12 01:46:46.194    1
# 2017-03-08 06:50:18.603    1
# 2017-03-08 08:42:07.169    1
# 2017-03-12 07:36:42.514    1
# 2017-03-08 17:17:51.845    1
# 2017-03-12 08:52:20.656    1
# 2017-03-08 16:12:38.337    1
# 2017-03-11 13:39:28.687    1
# 2017-03-09 14:30:50.940    1
# 2017-03-09 10:36:38.155    1
# Name: first_visit_time, dtype: int64
# ***********************************
# ip
# NaN    6485
# Name: ip, dtype: int64
# ***********************************
# is_first_day
# NaN    6485
# Name: is_first_day, dtype: int64
# ***********************************
# is_first_time
# NaN    6485
# Name: is_first_time, dtype: int64
# ***********************************
# latest_referrer
# NaN    6485
# Name: latest_referrer, dtype: int64
# ***********************************
# latest_referrer_host
# NaN    6485
# Name: latest_referrer_host, dtype: int64
# ***********************************
# latest_utm_campaign
# NaN    6485
# Name: latest_utm_campaign, dtype: int64
# ***********************************
# latest_utm_content
# NaN    6485
# Name: latest_utm_content, dtype: int64
# ***********************************
# latest_utm_medium
# NaN    6485
# Name: latest_utm_medium, dtype: int64
# ***********************************
# latest_utm_source
# NaN    6485
# Name: latest_utm_source, dtype: int64
# ***********************************
# latest_utm_term
# NaN    6485
# Name: latest_utm_term, dtype: int64
# ***********************************
# model
# NaN    6485
# Name: model, dtype: int64
# ***********************************
# os
# NaN    6485
# Name: os, dtype: int64
# ***********************************
# os_version
# NaN    6485
# Name: os_version, dtype: int64
# ***********************************
# referrer
# NaN    6485
# Name: referrer, dtype: int64
# ***********************************
# referrer_host
# NaN    6485
# Name: referrer_host, dtype: int64
# ***********************************
# screen_height
# NaN    6485
# Name: screen_height, dtype: int64
# ***********************************
# screen_width
# NaN    6485
# Name: screen_width, dtype: int64
# ***********************************
# title
# NaN    6485
# Name: title, dtype: int64
# ***********************************
# url
# NaN    6485
# Name: url, dtype: int64
# ***********************************
# url_path
# NaN    6485
# Name: url_path, dtype: int64
# ***********************************
# utm_campaign
# 通用词                            2731
# NaN                            2279
# S-通用词                           380
# 神策-移动推广                         345
# 首页                              321
# 品牌词                             315
# G-通用词                            80
# about                            13
# courses                           5
# 凤巢头条                              5
# 数据分析                              2
# trial                             2
# 皇冠子链                              2
# %E9%80%9A%E7%94%A8%E8%AF%8D       1
# ebizdemo                          1
# ivymobi                           1
# qiyukf                            1
# fxiaoke-cluster                   1
# Name: utm_campaign, dtype: int64
# ***********************************
# utm_content
# NaN                                                                          2312
# 通用-用户画像                                                                       607
# 通用-数据分析                                                                       520
# 通用词-三图                                                                        321
# 通用词-M                                                                         315
# 品牌-神策                                                                         310
# 通用-数据分析-产品                                                                    175
# 通用-用户分析                                                                       152
# 通用-APP运营                                                                      142
# 通用-数据分析-运营                                                                    142
# 通用-数据分析-行业                                                                    131
# 通用-数据处理                                                                       130
# 通用-电商运营                                                                       116
# 通用-数据可视化                                                                       87
# 通用-数据统计                                                                        85
# 通用-用户留存                                                                        78
# 通用-用户画像-产品                                                                     65
# 通用-用户行为分析                                                                      58
# 通用-大数据-行业                                                                      57
# 通用-大数据-其他                                                                      55
# 通用-网站运营                                                                        49
# 通用-数据系统                                                                        44
# 通用-用户留存-行业                                                                     43
# 通用-数据运营                                                                        38
# 通用-用户画像-功能                                                                     37
# 品牌词-M                                                                          30
# 通用-多维分析                                                                        27
# 通用-用户画像-行业                                                                     27
# 通用-广告优化                                                                        27
# 通用-数据统计-产品                                                                     27
#                                                                              ...
# 通用-数据分析-互联网                                                                    23
# 通用-数据分析-其他                                                                     22
# 通用-用户行为分析-系统                                                                   22
# 通用-数据指标                                                                        17
# 通用-数据分析法                                                                       17
# 通用-数据采集                                                                        17
# 通用-埋点                                                                          16
# 通用-用户行为分析-行业                                                                   15
# 通用-用户分析-产品                                                                     12
# 通用-数据运营-平台                                                                     12
# 通用-大数据-方案                                                                      12
# 通用-数据仓库                                                                         8
# 通用-数据分析-电商                                                                      8
# 通用-个性化营销                                                                        7
# 通用-数据分析-方案                                                                      7
# 品牌-神策-英文                                                                        5
# 通用-大数据-公司                                                                       4
# 通用-访客分析                                                                         4
# 通用-大数据-产品                                                                       4
# 通用-渠道追踪                                                                         3
# 通用-增长黑客                                                                         3
# 通用-可视化分析                                                                        2
# 通用-精准营销                                                                         2
# 通用-用户细分                                                                         2
# 通用-用户分群                                                                         2
# 通用-用户留存-提升                                                                      2
# %E9%80%9A%E7%94%A8-%E7%94%A8%E6%88%B7%E8%A1%8C%E4%B8%BA%E5%88%86%E6%9E%90       1
# 通用-用户行为分析-产品                                                                    1
# 通用-跨屏分析                                                                         1
# 通用-转化优化                                                                         1
# Name: utm_content, dtype: int64
# ***********************************
# utm_medium
# cpc           3132
# NaN           2278
# mcpc           750
# mfeed          321
# default          3
# production       1
# Name: utm_medium, dtype: int64
# ***********************************
# utm_source
# baidu            3713
# NaN              2253
# sogou             382
# google             81
# wechat             27
# sanjieke.cn        20
# next.36kr.com       3
# liquantao           1
# 23h5                1
# hzcaibin            1
# admin               1
# mulumu.com          1
# wangxuelin          1
# Name: utm_source, dtype: int64
# ***********************************
# utm_term
# NaN             2303
# 用户画像             613
# 首页-通用词-三图-图1     321
# 数据分析             260
# 神策               214
# 大数据分析            180
# 用户分析             136
# 电子商务数据           114
# 神策数据             110
# 产品数据分析            83
# 聚类分析              80
# app数据             76
# 网站数据统计            71
# 旅游大数据             61
# 数据挖掘              59
# app分析             56
# 网站运营数据分析          51
# 用户画像分析            43
# 数据分析工具            40
# 数据分析软件下载          38
# 数据处理              36
# 大数据应用             36
# 数据分析公司            36
# 客户画像              35
# 数据可视化             34
# 数据分析平台            31
# 日志分析系统            30
# app数据分析           30
# 数据建模              29
# 运营活动数据分析          27
#                 ...
# app用户行为            1
# 分析运营数据             1
# 多维分析工具             1
# 大数据 用户画像           1
# 用户画像标签             1
# 电商精准营销             1
# 用户画像产品             1
# 记录用户操作行为           1
# 移动游戏数据分析           1
# b2b用户画像            1
# 用户分群               1
# sem分析工具            1
# 移动应用数据分析           1
# 用户画像统计             1
# 提高转化率              1
# 第三方数据统计平台          1
# 数据分析app            1
# 网络运营数据分析           1
# 国内大数据分析            1
# 数据分析 页面            1
# 游戏用户行为分析           1
# 私有化部署              1
# 金融精准营销             1
# 数据系统建设             1
# 用户画像标签体系           1
# 广告效果监测系统           1
# 数据分析工具有哪些          1
# 精细化运营              1
# 国内数据可视化公司          1
# 游戏行业数据分析           1
# Name: utm_term, dtype: int64
# ***********************************
# latest_ch
# NaN    6485
# Name: latest_ch, dtype: int64
# ***********************************
# nocache
# 6.176569e+12    7
# 3.428791e+12    5
# 9.493710e+11    2
# 2.113082e+12    1
# 1.325193e+11    1
# 5.128380e+12    1
# 5.852592e+12    1
# 5.662013e+12    1
# 9.173899e+12    1
# 2.355384e+12    1
# 8.546932e+12    1
# 2.122514e+12    1
# 1.342249e+11    1
# 8.533637e+12    1
# 2.624756e+12    1
# 2.503958e+12    1
# 4.879898e+12    1
# 4.776127e+12    1
# 1.938919e+12    1
# 4.338716e+12    1
# 3.743618e+12    1
# 7.123896e+11    1
# 9.071799e+12    1
# 2.154256e+12    1
# 3.861720e+12    1
# 4.284920e+12    1
# 3.236849e+12    1
# 9.924676e+11    1
# 1.658672e+12    1
# 6.154389e+12    1
#                ..
# 3.881456e+12    1
# 1.669770e+12    1
# 4.206789e+12    1
# 4.091769e+11    1
# 8.723953e+12    1
# 6.399819e+12    1
# 1.715019e+12    1
# 4.388001e+12    1
# 5.860640e+12    1
# 5.793627e+12    1
# 6.961724e+12    1
# 8.040101e+12    1
# 7.470736e+12    1
# 2.474348e+11    1
# 9.398736e+12    1
# 7.084412e+12    1
# 3.635019e+12    1
# 6.137612e+12    1
# 6.494858e+12    1
# 3.210434e+12    1
# 6.371212e+12    1
# 6.674790e+12    1
# 7.376072e+12    1
# 9.098244e+12    1
# 3.870752e+11    1
# 9.239029e+12    1
# 3.644967e+12    1
# 7.519879e+12    1
# 6.973712e+12    1
# 1.624631e+12    1
# Name: nocache, dtype: int64
# ***********************************
# session_from_url
# NaN    6485
# Name: session_from_url, dtype: int64
# ***********************************
# session_referrer
# NaN    6485
# Name: session_referrer, dtype: int64
# ***********************************
# session_referrer_domain
# NaN    6485
# Name: session_referrer_domain, dtype: int64
# ***********************************
# session_referrer_host
# NaN    6485
# Name: session_referrer_host, dtype: int64
# ***********************************
# ch
# NaN          6434
# zhihu          32
# demo           11
# pedaily         2
# 36kr            2
# itjuzi          2
# chiyuan         1
# 36kr_cube       1
# Name: ch, dtype: int64
# ***********************************
# company
# NaN    6485
# b8ed671ac97ffa6d5cd63365bb5e0bb6574661f2    1
# 6f6990d589d8636f74aa9d7dc986da8854f8fc13    1
# 1e0e5e718d0042883dc0bda0ecb47885e4778470    1
# 759692bfee90057c89f69927f141cdbcfa3467a7    1
# ec4f931c68e224a062dfa6da8358d4668d3b62aa    1
# 8f829802aa00c14bbd20e9a504faa81457d99a1c    1
# 249e7d7e1bdd5d54da5a162bc5e2f5527a591af7    1
# d9408b9f70645f1703793151971ddc374f8ee9ec    1
# 12716c7ed6e344bd597a4763888eaec8a5d16fd0    1
# 6e199c1e0c0a8821bdc28fcd8408626d6f949cba    1
# 97dca60e292ab351c430afc8f039d4183f6a6ee0    1
# f56e5c0557f9eafd7ce976c2cf31ed545899f8ee    1
# Name: distinct_id, dtype: int64
# ***********************************
# email
# NaN    6485
# Name: email, dtype: int64
# ***********************************
# event
# NaN    6485
# Name: event, dtype: int64
# ***********************************
# from_url
# NaN    6485
# Name: from_url, dtype: int64
# ***********************************
# info
# NaN    6485
# Name: info, dtype: int64
# ***********************************
# isMsg
# NaN    6485
# Name: isMsg, dtype: int64
# ***********************************
# isSuccess
# NaN    6485
# Name: isSuccess, dtype: int64
# ***********************************
# jssdk_error
# NaN                6474
# cookieNotEnable      11
# Name: jssdk_error, dtype: int64
# ***********************************
# name
# NaN    6485
# Name: name, dtype: int64
# ***********************************
# page
# NaN    6485
# Name: page, dtype: int64
# ***********************************
# pagePosition
# NaN    6485
# Name: pagePosition, dtype: int64
# ***********************************
# pageStayTime
# NaN    6485
# Name: pageStayTime, dtype: int64
# ***********************************
# pageUrl
# NaN    6485
# Name: pageUrl, dtype: int64
# ***********************************
# project_name
# NaN    6485
# Name: project_name, dtype: int64
# ***********************************
# referrHostUrl
# NaN    6485
# Name: referrHostUrl, dtype: int64
# ***********************************
# referrerUrl
# NaN    6485
# Name: referrerUrl, dtype: int64
# ***********************************
# requestBtn
# NaN    6485
# Name: requestBtn, dtype: int64
# ***********************************
# result
# NaN    6485
# Name: result, dtype: int64
# ***********************************
# session_page_url
# NaN    6485
# Name: session_page_url, dtype: int64
# ***********************************
# siteUrl
# NaN    6485
# Name: siteUrl, dtype: int64
# ***********************************
# site_url
# NaN    6485
# Name: site_url, dtype: int64
# ***********************************
# time
# 1.490958e+12    33
# 1.490958e+12    18
# 1.490958e+12    17
# 1.490958e+12    17
# 1.490958e+12    16
# 1.490958e+12    15
# 1.490958e+12    15
# 1.490958e+12    14
# 1.490958e+12    14
# 1.490958e+12    13
# 1.490958e+12    13
# 1.490958e+12    13
# 1.490958e+12    13
# 1.490958e+12    13
# 1.490958e+12    12
# 1.490958e+12    12
# 1.490958e+12    12
# 1.490958e+12    12
# 1.490958e+12    12
# 1.490958e+12    12
# 1.490958e+12    12
# 1.490958e+12    12
# 1.490958e+12    12
# 1.490958e+12    11
# 1.490958e+12    11
# 1.490958e+12    11
# 1.490958e+12    11
# 1.490958e+12    11
# 1.490958e+12    11
# 1.490958e+12    11
#                 ..
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# 1.490958e+12     1
# Name: time, dtype: int64
# ***********************************
# type
# profile_set_once    6485
# Name: type, dtype: int64
# ***********************************
# url_path.1
# NaN    6485
# Name: url_path.1, dtype: int64
# ***********************************
# verification_code
# NaN    6485
# Name: verification_code, dtype: int64
# ***********************************
